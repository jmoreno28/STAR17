# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/lwebster/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
x =  np.arange(0.0, 1.0, 0.01)
y = np.sin(2*np.pi*x)

# %%
plt.plot(x,y)
plt.plot(2*x,y)

# %%
plt.plot(x,y)
